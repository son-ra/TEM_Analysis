# %%
import os
import matplotlib.pyplot as plt
import re
import numpy as np
from scipy import stats
#import optshrink as opt # package we create
import numpy as np
# import scipy.io as sio
import h5py
import matplotlib.pyplot as plt
import pandas as pd
import xarray as xr
import cartopy.crs as ccrs
import seaborn as sns
from shapely.geometry import Point
import geopandas as gp
from geodatasets import get_path
from shapely.geometry import Polygon

# %%
colnames_hurtt_nums = ['lon', 'lat', 'year', 'col1', 'col2', 'col3', 'col4', 'col5', 'col6', 'col7', 'col8', 'col9', 'col10', 'col11', 'col12', 'col13', 'col14', 'col15', 'col16', 'col17', 'col18', 'col19', 'col20', 'col21', 'col22']
colnames_hurtt = ['nlon','nlat','yr','totalarea','lf_regrid','vu_regrid','vc_regrid','vp_regrid','su_regrid','sc_regrid','sp_regrid','us_regrid','uc_regrid','up_regrid','cs_regrid','cu_regrid','cp_regrid','ps_regrid','pu_regrid','pc_regrid','vs1_regrid','vs2_regrid','ss1_regrid','ss2_regrid','vs_regrid']

colnames_lulc = ['lon', 'lat', 'variable', 'year', 'cohort number', 'cohort source number', 'stand age', 'cohort area ', 
'potential natural vegetaion', 'current vegetation', 'vegetation subtype', 'lc state', 'previous years lc state', 
'fert flag', 'irrg flag', 'till flag', 'disturbance type', 'disturbance month', 'fire return interval',
'th1', 'th2', 'th3', 'th4', 'th5', 'th6', 'country']

colnames_max = ['lon', 'lat', 'variable', 'total land area', 'year', 'total number of cohorts',
                'number of natural cohorts', 'region']

# %%
#### read in lulcc for region 1, merge and compare years


cru = pd.read_csv('/group/moniergrp/TEM_Large_Ensemble/input_files/cru_regions/region_1/output_LULCCRT.txt', names = colnames_lulc)

# %%
cmip6 = pd.read_csv('/group/moniergrp/TEM_Large_Ensemble/input_files/large_ensemble/region_1/lulcc/historical/lulcc_1851_2014.txt', names = colnames_lulc)

# %%
cru.loc[cru['year']==2014]
# Out:
#            lon   lat    variable  year  cohort number  cohort source number  \
# 21109   -177.0 -44.0   LULCCHRT   2014              1                     1
# 21110   -177.0 -44.0   LULCCHRT   2014              2                     1
# 21111   -177.0 -44.0   LULCCHRT   2014              3                     1
# 21112   -177.0 -44.0   LULCCHRT   2014              4                     1
# 21113   -177.0 -44.0   LULCCHRT   2014              5                     1
# ...        ...   ...         ...   ...            ...                   ...
# 8296440 -120.0  54.0   LULCCHRT   2014            177                     1
# 8296441 -120.0  54.0   LULCCHRT   2014            178                     1
# 8296442 -120.0  54.0   LULCCHRT   2014            179                     1
# 8296443 -120.0  54.0   LULCCHRT   2014            180                    93
# 8296444 -120.0  54.0   LULCCHRT   2014            181                     1
#
#          stand age  cohort area   potential natural vegetaion  \
# 21109         3000             0                           33
# 21110           43             6                           33
# 21111           40             1                           33
# 21112           15             4                           33
# 21113           15            11                           33
# ...            ...           ...                          ...
# 8296440          3             7                            4
# 8296441          2             7                            4
# 8296442          1             7                            4
# 8296443          1             1                            4
# 8296444          0             7                            4
#
#          current vegetation  ...  disturbance type  disturbance month  \
# 21109                    33  ...                 0                  0
# 21110                    51  ...                 0                  0
# 21111                    51  ...                 0                  0
# 21112                    51  ...                 0                  0
# 21113                    51  ...                 0                  0
# ...                     ...  ...               ...                ...
# 8296440                   4  ...                 0                  0
# 8296441                   4  ...                 0                  0
# 8296442                   4  ...                 0                  0
# 8296443                   4  ...                 0                  0
# 8296444                   4  ...                 2                  1
#
#          fire return interval   th1  th2  th3  th4   th5  th6       country
# 21109                    2000  0.00  0.0  0.0  0.0  0.00  0.0   New_Zealand
# 21110                    2000  0.33  0.6  0.3  0.1  0.01  0.0   New_Zealand
# 21111                    2000  0.33  0.6  0.3  0.1  0.01  0.0   New_Zealand
# 21112                    2000  0.33  0.6  0.3  0.1  0.01  0.0   New_Zealand
# 21113                    2000  0.33  0.6  0.3  0.1  0.01  0.0   New_Zealand
# ...                       ...   ...  ...  ...  ...   ...  ...           ...
# 8296440                  2000  0.33  0.6  0.3  0.1  0.01  0.0        Canada
# 8296441                  2000  0.33  0.6  0.3  0.1  0.01  0.0        Canada
# 8296442                  2000  0.33  0.6  0.3  0.1  0.01  0.0        Canada
# 8296443                  2000  0.33  0.6  0.3  0.1  0.01  0.0        Canada
# 8296444                  2000  0.33  0.6  0.3  0.1  0.01  0.0        Canada
#
# [86143 rows x 26 columns]

# %%
cmip6.loc[cmip6['year']==2014]
# Out:
#            lon   lat    variable  year  cohort number  cohort source number  \
# 9543    -177.0 -44.0   LULCCHRT   2014              1                     1
# 9544    -177.0 -44.0   LULCCHRT   2014              2                     1
# 9545    -177.0 -44.0   LULCCHRT   2014              3                     1
# 9546    -177.0 -44.0   LULCCHRT   2014              4                     1
# 9547    -177.0 -44.0   LULCCHRT   2014              5                     1
# ...        ...   ...         ...   ...            ...                   ...
# 7295651 -120.0  54.0   LULCCHRT   2014            138                     1
# 7295652 -120.0  54.0   LULCCHRT   2014            139                     1
# 7295653 -120.0  54.0   LULCCHRT   2014            140                     1
# 7295654 -120.0  54.0   LULCCHRT   2014            141                     1
# 7295655 -120.0  54.0   LULCCHRT   2014            142                     1
#
#          stand age  cohort area   potential natural vegetaion  \
# 9543          3000           385                           33
# 9544            40             1                           33
# 9545            34             1                           33
# 9546             7             1                           33
# 9547            47             1                           33
# ...            ...           ...                          ...
# 7295651          3             5                            4
# 7295652          2             1                            4
# 7295653          2             7                            4
# 7295654          1             5                            4
# 7295655          0             6                            4
#
#          current vegetation  ...  disturbance type  disturbance month  \
# 9543                     33  ...                 0                  0
# 9544                     51  ...                 0                  0
# 9545                     51  ...                 0                  0
# 9546                     51  ...                 0                  0
# 9547                     33  ...                 0                  0
# ...                     ...  ...               ...                ...
# 7295651                   4  ...                 0                  0
# 7295652                  50  ...                 0                  0
# 7295653                   4  ...                 0                  0
# 7295654                   4  ...                 0                  0
# 7295655                   4  ...                 2                  1
#
#          fire return interval   th1  th2  th3  th4   th5  th6       country
# 9543                     2000  0.00  0.0  0.0  0.0  0.00  0.0   New_Zealand
# 9544                     2000  0.33  0.6  0.3  0.1  0.01  0.0   New_Zealand
# 9545                     2000  0.33  0.6  0.3  0.1  0.01  0.0   New_Zealand
# 9546                     2000  0.33  0.6  0.3  0.1  0.01  0.0   New_Zealand
# 9547                     2000  0.33  0.6  0.3  0.1  0.01  0.0   New_Zealand
# ...                       ...   ...  ...  ...  ...   ...  ...           ...
# 7295651                  2000  0.33  0.6  0.3  0.1  0.01  0.0        Canada
# 7295652                  2000  0.33  0.6  0.3  0.1  0.01  0.0        Canada
# 7295653                  2000  0.33  0.6  0.3  0.1  0.01  0.0        Canada
# 7295654                  2000  0.33  0.6  0.3  0.1  0.01  0.0        Canada
# 7295655                  2000  0.33  0.6  0.3  0.1  0.01  0.0        Canada
#
# [83566 rows x 26 columns]
